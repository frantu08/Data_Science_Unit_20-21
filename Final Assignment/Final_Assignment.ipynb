# %% [markdown]
# # Final Assignment

# %% [markdown]
# # Practical 1

# %% [markdown]
# ## Step 1: Uploading and inspecting the data

# %%
import pandas as pd
import os

clothing = pd.read_csv("e-shop data and description/e-shop clothing 2008.csv",delimiter=";")

clothing.head()
# Out:
#    year  month  day  order  country  session ID  page 1 (main category)  \
# 0  2008      4    1      1       29           1                       1
# 1  2008      4    1      2       29           1                       1
# 2  2008      4    1      3       29           1                       2
# 3  2008      4    1      4       29           1                       2
# 4  2008      4    1      5       29           1                       2
#
#   page 2 (clothing model)  colour  location  model photography  price  \
# 0                     A13       1         5                  1     28
# 1                     A16       1         6                  1     33
# 2                      B4      10         2                  1     52
# 3                     B17       6         6                  2     38
# 4                      B8       4         3                  2     52
#
#    price 2  page
# 0        2     1
# 1        2     1
# 2        1     1
# 3        2     1
# 4        1     1

# %%
clothing.columns
# Out:
# Index(['year', 'month', 'day', 'order', 'country', 'session ID',
#        'page 1 (main category)', 'page 2 (clothing model)', 'colour',
#        'location', 'model photography', 'price', 'price 2', 'page'],
#       dtype='object')

# %%
clothing['year'].value_counts()
# Out:
# 2008    165474
# Name: year, dtype: int64

# %%
clothing['month'].value_counts()
# Out:
# 4    48199
# 5    35654
# 7    35231
# 6    32242
# 8    14148
# Name: month, dtype: int64

# %%
clothing['day'].value_counts()
# Out:
# 2     7216
# 1     7072
# 8     6695
# 4     6416
# 11    6379
# 6     6233
# 12    6182
# 7     6170
# 5     6167
# 10    6161
# 3     6104
# 9     5977
# 16    5752
# 29    5405
# 14    5332
# 23    5109
# 24    5066
# 17    5059
# 21    5023
# 22    4864
# 18    4824
# 25    4793
# 19    4789
# 28    4659
# 15    4618
# 20    4563
# 13    4389
# 30    4336
# 27    4199
# 26    4103
# 31    1819
# Name: day, dtype: int64

# %%
# ORDER -> sequence of clicks during one session
clothing['order'].value_counts()
# Out:
# 1      24026
# 2      18984
# 3      15664
# 4      13044
# 5      11007
#        ...
# 187        2
# 190        2
# 195        1
# 193        1
# 194        1
# Name: order, Length: 195, dtype: int64

# %%
clothing['country'].value_counts()
# Out:
# 29    133963
# 9      18003
# 24      4091
# 46      2522
# 44      1385
# 16       834
# 21       811
# 34       716
# 41       684
# 3        256
# 27       227
# 12       210
# 42       170
# 37       163
# 10       152
# 31       144
# 22       144
# 28       139
# 38       137
# 15       125
# 11       115
# 25        71
# 2         58
# 32        49
# 23        46
# 14        43
# 39        34
# 43        31
# 19        29
# 17        23
# 36        19
# 18        18
# 20        10
# 7          9
# 47         7
# 45         6
# 30         5
# 6          5
# 5          4
# 33         3
# 35         3
# 1          3
# 13         2
# 26         2
# 8          1
# 4          1
# 40         1
# Name: country, dtype: int64

# %%
clothing['session ID'].value_counts()
# Out:
# 22433    195
# 13846    192
# 22902    185
# 8201     161
# 19623    142
#         ...
# 16231      1
# 13767      1
# 22378      1
# 4065       1
# 2047       1
# Name: session ID, Length: 24026, dtype: int64

# %%
clothing['page 1 (main category)'].value_counts()
# PAGE 1 (MAIN CATEGORY) -> concerns the main product category:
# 1-trousers
# 2-skirts
# 3-blouses
# 4-sale
# Out:
# 1    49742
# 4    38747
# 3    38577
# 2    38408
# Name: page 1 (main category), dtype: int64

# %%
clothing['page 2 (clothing model)'].value_counts()
# PAGE 2 (CLOTHING MODEL) -> contains information about the code for each product 
# (217 products)
# Out:
# B4     3579
# A2     3013
# A11    2789
# P1     2681
# B10    2566
#        ...
# P66      46
# P22       2
# P79       2
# P28       1
# P54       1
# Name: page 2 (clothing model), Length: 217, dtype: int64

# %%
clothing['colour'].value_counts()
# Out:
# 2     29764
# 3     29259
# 6     17476
# 4     16517
# 14    15939
# 9     13531
# 12     8830
# 1      7785
# 7      6876
# 13     6295
# 11     5292
# 10     3579
# 8      2664
# 5      1667
# Name: colour, dtype: int64

# %%
clothing['colour'].value_counts().count()
# Out:
# 14

# %%
clothing['location'].value_counts()
# LOCATION -> photo location on the page, the screen has been divided into six parts:

# 1-top left
# 2-top in the middle
# 3-top right
# 4-bottom left
# 5-bottom in the middle
# 6-bottom right
# Out:
# 1    34532
# 2    33383
# 5    27783
# 4    27377
# 3    21656
# 6    20743
# Name: location, dtype: int64

# %%
clothing['model photography'].value_counts()
# Out:
# 1    122439
# 2     43035
# Name: model photography, dtype: int64

# %%
clothing['price'].value_counts()
# Out:
# 38    33883
# 43    22751
# 33    18749
# 28    18262
# 48    17878
# 62    14383
# 57    11884
# 52     9279
# 23     3992
# 67     3811
# 72     1932
# 82     1923
# 60     1641
# 20     1433
# 55     1199
# 26      844
# 50      764
# 65      402
# 18      280
# 77      184
# Name: price, dtype: int64

# %%
clothing['price'].value_counts().count()
# Out:
# 20

# %%
clothing['price 2'].value_counts()
# Out:
# 1    84695
# 2    80779
# Name: price 2, dtype: int64

# %%
clothing['page'].value_counts()
# Out:
# 1    93452
# 2    41037
# 3    19301
# 4     8861
# 5     2823
# Name: page, dtype: int64

# %%
clothing
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 0       2008      4    1      1       29           1                       1
# 1       2008      4    1      2       29           1                       1
# 2       2008      4    1      3       29           1                       2
# 3       2008      4    1      4       29           1                       2
# 4       2008      4    1      5       29           1                       2
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165469  2008      8   13      1       29       24024                       2
# 165470  2008      8   13      1        9       24025                       1
# 165471  2008      8   13      1       34       24026                       1
# 165472  2008      8   13      2       34       24026                       3
# 165473  2008      8   13      3       34       24026                       2
#
# ...

# %%
clothing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165474 entries, 0 to 165473
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     165474 non-null  int64
#  1   month                    165474 non-null  int64
#  2   day                      165474 non-null  int64
#  3   order                    165474 non-null  int64
#  4   country                  165474 non-null  int64
#  5   session ID               165474 non-null  int64
#  6   page 1 (main category)   165474 non-null  int64
#  7   page 2 (clothing model)  165474 non-null  object
#  8   colour                   165474 non-null  int64
#  9   location                 165474 non-null  int64
#  10  model photography        165474 non-null  int64
#  11  price                    165474 non-null  int64
#  12  price 2                  165474 non-null  int64
#  13  page                     165474 non-null  int64
# ...

# %%
clothing.describe()
# Out:
#            year          month            day          order        country  \
# count  165474.0  165474.000000  165474.000000  165474.000000  165474.000000
# mean     2008.0       5.585887      14.524554       9.817476      26.952621
# std         0.0       1.328160       8.830374      13.478411       7.150691
# min      2008.0       4.000000       1.000000       1.000000       1.000000
# 25%      2008.0       4.000000       7.000000       2.000000      29.000000
# 50%      2008.0       5.000000      14.000000       6.000000      29.000000
# 75%      2008.0       7.000000      22.000000      12.000000      29.000000
# max      2008.0       8.000000      31.000000     195.000000      47.000000
#
#           session ID  page 1 (main category)         colour       location  \
# count  165474.000000           165474.000000  165474.000000  165474.000000
# mean    12058.417056                2.400842       6.227655       3.258198
# ...

# %%
# %matplotlib inline 
#so that the plot will be displayed in the notebook
import matplotlib.pyplot as plt

clothing.hist(bins=50, figsize=(20,15))
plt.show()
